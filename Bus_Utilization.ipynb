# %%
###########################
### Author: Hakan Toguc ###
### Date : 17-Jun-2021  ###
###########################

# This study intended to forecast bus demands of municipalities in Banana Republic

import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, RepeatVector, TimeDistributed
from sklearn.metrics import mean_absolute_error
from collections import OrderedDict

# %%
# Reading the dataset file and performing operations on it 
df_raw = pd.read_csv("municipality_bus_utilization.csv", header=0,)
df_raw.sort_values(["timestamp",],inplace=True,ascending=True)
df_raw.reset_index(drop=True,inplace=True)

# In order to scale "usage" parameter we used "usage/total_capacity"
df_raw["usage_ratio"] = df_raw["usage"] / df_raw["total_capacity"]

# we record each municipality's total_capacity into a dictionary variable
dict_capacity = dict()
for row in df_raw.itertuples():
    if row.municipality_id not in dict_capacity:
        dict_capacity[row.municipality_id] = row.total_capacity
df_raw.drop(columns=["usage","total_capacity"],inplace=True)
df_raw['timestamp_ts'] = pd.to_datetime(df_raw['timestamp'])

# In order to define start and end of one week interval, we find out day of week
df_raw["dayofweek"] = df_raw['timestamp_ts'].dt.dayofweek
df_raw["date"] = df_raw["timestamp"].apply(func=lambda x: str(x)[:10])

# if minute value of timestamp is above 45 then we accept it as next hour value
df_raw["order"] = df_raw["timestamp"].apply(
    func=lambda x: int(str(x)[11:13]) + 1 if str(x)[14:16] > "45" else int(str(x)[11:13]))

# we accept largest usage_ratio out of more than one usage data during an hour
df_hourly = df_raw.groupby(["date", "municipality_id", "dayofweek",
                "order"]).agg({'usage_ratio': 'max', })[['usage_ratio', ]].reset_index()
df_hourly = df_hourly.sort_values(["date", "order"])

# pivot table is generated to sum up daily data on a single line
df_pivot = pd.pivot_table(data=df_hourly, values="usage_ratio",
                               index=["date", "municipality_id", "dayofweek"], columns="order")
df_pivot.reset_index(drop=False, inplace=True)

# test part of the data is seperated
df_testweek_1 = df_pivot.loc[(df_pivot["date"] > "2017-08-05") &
                                       (df_pivot["date"] < "2017-08-13")].reset_index(drop=True)
df_testweek_2 = df_pivot.loc[(df_pivot["date"] > "2017-08-12")].reset_index(drop=True)
df_pivot.drop(df_pivot[df_pivot["date"] > "2017-08-05"].index, inplace=True)

# missing dates' values are calculated using median, depending on which day of the week
weekday_medians = df_pivot.groupby(by=["dayofweek", "municipality_id"], ).median()

# missing dates and their dayofweek values are given below
missing_days = [("2017-06-20", 1), ("2017-06-21", 2), ("2017-07-31", 0), ("2017-08-03", 3), ("2017-08-04", 4)]
municipality_count = df_raw["municipality_id"].nunique()
for day in missing_days:
    for municipality_id in range(municipality_count):
        # missing rows are gerenerated
        new_row = {"date": day[0], "municipality_id": municipality_id, "dayofweek": day[1]}
        for hour in range(8, 17):
            new_row[hour] = weekday_medians.loc[(day[1], municipality_id), hour]
        # newly generated missing row is appended to training data
        df_pivot = df_pivot.append(new_row, ignore_index=True)
df_pivot = df_pivot.sort_values("date").reset_index(drop=True)

# %%
# our training data with usage ratio given in hour columns (8,9,10,.....16) 
print(df_pivot.head())
# Out:
#          date  municipality_id  dayofweek         8         9        10  \
# 0  2017-06-04                0          6  0.087807  0.152506  0.189833
# 1  2017-06-04                1          6  0.347607  0.536524  0.687657
# 2  2017-06-04                2          6  0.446198  0.606887  0.773314
# 3  2017-06-04                3          6  0.398964  0.585492  0.690674
# 4  2017-06-04                4          6  0.379142  0.645004  0.781916
#
#          11        12        13        14        15        16
# 0  0.212229  0.218272  0.215073  0.207963  0.191255  0.167081
# 1  0.838791  0.863980  0.861461  0.858942  0.795970  0.702771
# 2  0.879484  0.942611  0.946915  0.926829  0.863702  0.746055
# 3  0.744560  0.761140  0.754922  0.745596  0.720207  0.635751
# 4  0.829694  0.837400  0.832520  0.810172  0.775751  0.684562

# %%
# First test week data
print(df_testweek_1.head())
# Out:
# order        date  municipality_id  dayofweek         8         9        10  \
# 0      2017-08-06                0          6  0.116957  0.163171  0.202275
# 1      2017-08-06                1          6  0.544081  0.662469  0.838791
# 2      2017-08-06                2          6  0.446198  0.558106  0.720230
# 3      2017-08-06                3          6  0.406218  0.595337  0.692746
# 4      2017-08-06                4          6  0.549705  0.723863  0.810172
#
# order        11        12        13        14        15        16
# 0      0.230359  0.232137  0.233914  0.229293  0.212584  0.188411
# 1      1.002519  1.000000  1.005038  1.007557  0.942065  0.863980
# 2      0.807747  0.862267  0.939742  0.932568  0.859397  0.784792
# 3      0.792228  0.805181  0.807254  0.807254  0.755959  0.665803
# 4      0.875417  0.884151  0.883380  0.876702  0.827126  0.729258

# %%
# Second test week data
print(df_testweek_2.head())
# Out:
# order        date  municipality_id  dayofweek         8         9        10  \
# 0      2017-08-13                0          6  0.111625  0.162105  0.195876
# 1      2017-08-13                1          6  0.549118  0.710327  0.889169
# 2      2017-08-13                2          6  0.690100  0.822095  0.880918
# 3      2017-08-13                3          6  0.399482  0.582383  0.719689
# 4      2017-08-13                4          6  0.438736  0.668636  0.822759
#
# order        11        12        13        14        15        16
# 0      0.219339  0.225738  0.226093  0.225027  0.199431  0.175613
# 1      1.010076  1.032746  1.035264  1.025189  0.924433  0.851385
# 2      0.807747  0.889527  0.928264  0.959828  0.855093  0.737446
# 3      0.779793  0.805181  0.810363  0.800000  0.756477  0.656477
# 4      0.886720  0.901105  0.898793  0.886720  0.846134  0.745441

# %%
# Each municipality handled alone to generate ML models, thus there are 10 models in total
# Evaluations are performed after combining the predictions of all models

# %%
# to store municipality based evaluations
evaluation_dict = OrderedDict()
y_true_week1_total = []
y_pred_week1_total = []
y_true_week2_total = []
y_pred_week2_total = []

# %%
def train(municipality_id):
    """ Model design, data customization and training are performed here
        only one municipality's model is trained at ones """
    train_data = df_pivot.loc[df_pivot["municipality_id"] == municipality_id]
    train_data = train_data.sort_values(by=["date",]).reset_index(drop=True)
    # hourly usage_ratio values are used as training data
    train_data = train_data[[8,9,10,11,12,13,14,15,16]].values
    X = []
    y = []
    # we used 7-day-data as one sequence and customized input and labeled data accordingly
    loop_count = int(len(train_data)/7)
    for ind in range(loop_count):
        if ind == loop_count-1:
            break
        X.append(train_data[ind*7:(ind+1)*7])
        y.append(train_data[(ind+1)*7:(ind+2)*7])
    X = np.array(X)
    y = np.array(y)

    # setting up our neural network model
    # input shape is 7-day-data of one municipality
    # for each day there are 9 hours usage data
    model = Sequential()
    model.add(LSTM(126,input_shape=(7,9),))
    model.add(RepeatVector(7))
    model.add(LSTM(126, return_sequences=True))
    model.add(Dense(126,))
    model.add(Dense(63,))
    model.add(TimeDistributed(Dense(9,)))
    model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mae'])
    model.fit(X, y, epochs=60, batch_size=5, verbose=1)
    return model,y

# %%
def evaluation_test_week_1(municipality_id, model, y):
    """ First test week evaluation of each municipality is performed """
    global evaluation_dict,y_true_week1_total,y_pred_week1_total
    # to predict the first test week, we use last week of training data as input
    y_pred_week1 = model.predict(y[-1].reshape(1, y[-1].shape[0], y[-1].shape[1]))
    # we filter single municipality's test week 1 data
    df_testweek1_filt = df_testweek_1.loc[df_testweek_1["municipality_id"] == municipality_id]
    df_testweek1_filt = df_testweek1_filt.sort_values(["date",]).reset_index(drop=True)
    np_testweek1_filt = df_testweek1_filt[[8, 9, 10, 11, 12, 13, 14, 15, 16]].values
    # we transform one week 2-dim array datas to flat arrays, to facilitate evaluation
    y_pred_week1_flat = np.reshape(y_pred_week1,(-1,))
    np_testweek1_filt_flat = np.reshape(np_testweek1_filt,(-1,))
    # we used real usage values to calculate error metric, not usage_ratios like in training
    mae1 = mean_absolute_error(y_true=np_testweek1_filt_flat * dict_capacity[municipality_id],
                                      y_pred=y_pred_week1_flat * dict_capacity[municipality_id])
    print("mae_week1 for municipality = {} is {:.2f}".format(municipality_id, mae1))
    evaluation_dict[municipality_id] = [mae1,]
    y_true_week1_total = y_true_week1_total + list(np_testweek1_filt_flat * dict_capacity[municipality_id])
    y_pred_week1_total += list(y_pred_week1_flat * dict_capacity[municipality_id])
    return model,np_testweek1_filt

# %%
def evaluation_test_week_2(municipality_id, model, np_testweek1_filt):
    """ Second test week evaluation of each municipality is performed """
    global evaluation_dict,y_true_week2_total,y_pred_week2_total
    # to predict the second test week, we use first test week data as input
    y_pred_week2 = model.predict(np_testweek1_filt.reshape(1, np_testweek1_filt.shape[0],
                                                                np_testweek1_filt.shape[1]))
    # we filter single municipality's test week 2 data
    df_testweek2_filt = df_testweek_2.loc[df_testweek_2["municipality_id"] == municipality_id]
    df_testweek2_filt = df_testweek2_filt.sort_values(["date", ]).reset_index(drop=True)
    np_testweek2_filt = df_testweek2_filt[[8, 9, 10, 11, 12, 13, 14, 15, 16]].values
    # we transform one week 2-dim array datas to flat arrays, to facilitate evaluation
    y_pred_week2_flat = np.reshape(y_pred_week2,(-1,))
    np_testweek2_filt_flat = np.reshape(np_testweek2_filt,(-1,))
    # we used real usage values to calculate error metric, not usage_ratios like in training
    mae2 = mean_absolute_error(y_true=np_testweek2_filt_flat * dict_capacity[municipality_id],
                                      y_pred=y_pred_week2_flat * dict_capacity[municipality_id])
    print("mae_week2 for municipality = {} is {:.2f}".format(municipality_id, mae2))
    evaluation_dict[municipality_id].append(mae2)
    y_true_week2_total += list(np_testweek2_filt_flat * dict_capacity[municipality_id])
    y_pred_week2_total += list(y_pred_week2_flat * dict_capacity[municipality_id])

# %%
def overall_evaluation():
    """ Single test week and both test weeks evaluation of all municipalities are performed """
    # First test week error calculation for all municipalities combined
    mae_week_1 = mean_absolute_error(y_true=y_true_week1_total,y_pred=y_pred_week1_total)
    print()
    print("**************** RESULTS *********************")
    print()
    print("mae_week1 for all municipalities is {:.2f}".format(mae_week_1))
    # Second test week error calculation for all municipalities combined
    mae_week_2 = mean_absolute_error(y_true=y_true_week2_total, y_pred=y_pred_week2_total)
    print("mae_week2 for all municipalities is {:.2f}".format(mae_week_2))
    # Ultimate error calculation of both test weeks and all municipalities combined
    mae_overall = mean_absolute_error(y_true=y_true_week1_total+y_true_week2_total,
                                      y_pred=y_pred_week1_total+y_pred_week2_total)
    print("mae_overall for all municipalities and both weeks combined is {:.2f}".format(mae_overall))

# %%
municipality_count = 10
for municipality_id in range(municipality_count):
    model,y = train(municipality_id)
    model,np_testweek1_filt = evaluation_test_week_1(municipality_id, model, y)
    evaluation_test_week_2(municipality_id, model, np_testweek1_filt)
print()
print("Dictionary of each municipality MAE evaluation on TestWeek 1 and TestWeek 2")
print("---------------------------------------------------------------------------")
print(evaluation_dict)
overall_evaluation()

# **************** RESULTS *********************
#
# mae_week1 for all municipalities is 118.58
# mae_week2 for all municipalities is 161.24
# mae_overall for all municipalities and both weeks combined is 139.91
# Out:
# Epoch 1/60
# 2/2 [==============================] - 3s 11ms/step - loss: 0.1866 - mae: 0.1866
# Epoch 2/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1074 - mae: 0.1074
# Epoch 3/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0884 - mae: 0.0884
# Epoch 4/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0839 - mae: 0.0839
# Epoch 5/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0728 - mae: 0.0728
# Epoch 6/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0692 - mae: 0.0692
# Epoch 7/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0607 - mae: 0.0607
# Epoch 8/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0560 - mae: 0.0560
# Epoch 9/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0538 - mae: 0.0538
# Epoch 10/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0516 - mae: 0.0516
# Epoch 11/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0468 - mae: 0.0468
# Epoch 12/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0434 - mae: 0.0434
# Epoch 13/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0427 - mae: 0.0427
# Epoch 14/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0410 - mae: 0.0410
# Epoch 15/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0391 - mae: 0.0391
# Epoch 16/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0379 - mae: 0.0379
# Epoch 17/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0381 - mae: 0.0381
# Epoch 18/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0373 - mae: 0.0373
# Epoch 19/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0366 - mae: 0.0366
# Epoch 20/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0366 - mae: 0.0366
# Epoch 21/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0360 - mae: 0.0360
# Epoch 22/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0361 - mae: 0.0361
# Epoch 23/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0354 - mae: 0.0354
# Epoch 24/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0354 - mae: 0.0354
# Epoch 25/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0351 - mae: 0.0351
# Epoch 26/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0363 - mae: 0.0363
# Epoch 27/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0346 - mae: 0.0346
# Epoch 28/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0352 - mae: 0.0352
# Epoch 29/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0359 - mae: 0.0359
# Epoch 30/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0346 - mae: 0.0346
# Epoch 31/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0346 - mae: 0.0346
# Epoch 32/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0352 - mae: 0.0352
# Epoch 33/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0346 - mae: 0.0346
# Epoch 34/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0345 - mae: 0.0345
# Epoch 35/60
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0348 - mae: 0.0348
# Epoch 36/60
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0340 - mae: 0.0340
# Epoch 37/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0343 - mae: 0.0343
# Epoch 38/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0345 - mae: 0.0345
# Epoch 39/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0338 - mae: 0.0338
# Epoch 40/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0345 - mae: 0.0345
# Epoch 41/60
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0341 - mae: 0.0341
# Epoch 42/60
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0343 - mae: 0.0343
# Epoch 43/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0342 - mae: 0.0342
# Epoch 44/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0335 - mae: 0.0335
# Epoch 45/60
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0337 - mae: 0.0337
# Epoch 46/60
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0335 - mae: 0.0335
# Epoch 47/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0336 - mae: 0.0336
# Epoch 48/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0333 - mae: 0.0333
# Epoch 49/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0334 - mae: 0.0334
# Epoch 50/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0332 - mae: 0.0332
# Epoch 51/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0336 - mae: 0.0336
# Epoch 52/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0337 - mae: 0.0337
# Epoch 53/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0328 - mae: 0.0328
# Epoch 54/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0343 - mae: 0.0343
# Epoch 55/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0337 - mae: 0.0337
# Epoch 56/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0331 - mae: 0.0331
# Epoch 57/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0330 - mae: 0.0330
# Epoch 58/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0329 - mae: 0.0329
# Epoch 59/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0328 - mae: 0.0328
# Epoch 60/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0330 - mae: 0.0330
# mae_week1 for municipality = 0 is 49.88
# mae_week2 for municipality = 0 is 324.48
# Epoch 1/60
# 2/2 [==============================] - 3s 11ms/step - loss: 0.7099 - mae: 0.7099
# Epoch 2/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4450 - mae: 0.4450
# Epoch 3/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3044 - mae: 0.3044
# Epoch 4/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3024 - mae: 0.3024
# Epoch 5/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2360 - mae: 0.2360
# Epoch 6/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2407 - mae: 0.2407
# Epoch 7/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2213 - mae: 0.2213
# Epoch 8/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1912 - mae: 0.1912
# Epoch 9/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1868 - mae: 0.1868
# Epoch 10/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1765 - mae: 0.1765
# Epoch 11/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1595 - mae: 0.1595
# Epoch 12/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1463 - mae: 0.1463
# Epoch 13/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1398 - mae: 0.1398
# Epoch 14/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1239 - mae: 0.1239
# Epoch 15/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1238 - mae: 0.1238
# Epoch 16/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1197 - mae: 0.1197
# Epoch 17/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1134 - mae: 0.1134
# Epoch 18/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1074 - mae: 0.1074
# Epoch 19/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1037 - mae: 0.1037
# Epoch 20/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1013 - mae: 0.1013
# Epoch 21/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0993 - mae: 0.0993
# Epoch 22/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0986 - mae: 0.0986
# Epoch 23/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0935 - mae: 0.0935
# Epoch 24/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0914 - mae: 0.0914
# Epoch 25/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0909 - mae: 0.0909
# Epoch 26/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0907 - mae: 0.0907
# Epoch 27/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0858 - mae: 0.0858
# Epoch 28/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0895 - mae: 0.0895
# Epoch 29/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0835 - mae: 0.0835
# Epoch 30/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0826 - mae: 0.0826
# Epoch 31/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0830 - mae: 0.0830
# Epoch 32/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0794 - mae: 0.0794
# Epoch 33/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0825 - mae: 0.0825
# Epoch 34/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0808 - mae: 0.0808
# Epoch 35/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0775 - mae: 0.0775
# Epoch 36/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0817 - mae: 0.0817
# Epoch 37/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0791 - mae: 0.0791
# Epoch 38/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0770 - mae: 0.0770
# Epoch 39/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0770 - mae: 0.0770
# Epoch 40/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0774 - mae: 0.0774
# Epoch 41/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0767 - mae: 0.0767
# Epoch 42/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0770 - mae: 0.0770
# Epoch 43/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0728 - mae: 0.0728
# Epoch 44/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0760 - mae: 0.0760
# Epoch 45/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0747 - mae: 0.0747
# Epoch 46/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0742 - mae: 0.0742
# Epoch 47/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0730 - mae: 0.0730
# Epoch 48/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0767 - mae: 0.0767
# Epoch 49/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0751 - mae: 0.0751
# Epoch 50/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0778 - mae: 0.0778
# Epoch 51/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0865 - mae: 0.0865
# Epoch 52/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0748 - mae: 0.0748
# Epoch 53/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0917 - mae: 0.0917
# Epoch 54/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0744 - mae: 0.0744
# Epoch 55/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0807 - mae: 0.0807
# Epoch 56/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0852 - mae: 0.0852
# Epoch 57/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0842 - mae: 0.0842
# Epoch 58/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0769 - mae: 0.0769
# Epoch 59/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0727 - mae: 0.0727
# Epoch 60/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0730 - mae: 0.0730
# mae_week1 for municipality = 1 is 45.05
# mae_week2 for municipality = 1 is 22.62
# Epoch 1/60
# 2/2 [==============================] - 3s 12ms/step - loss: 0.6458 - mae: 0.6458
# Epoch 2/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4333 - mae: 0.4333
# Epoch 3/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3158 - mae: 0.3158
# Epoch 4/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2949 - mae: 0.2949
# Epoch 5/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2262 - mae: 0.2262
# Epoch 6/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2465 - mae: 0.2465
# Epoch 7/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2273 - mae: 0.2273
# Epoch 8/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2075 - mae: 0.2075
# Epoch 9/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1959 - mae: 0.1959
# Epoch 10/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1740 - mae: 0.1740
# Epoch 11/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1745 - mae: 0.1745
# Epoch 12/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1661 - mae: 0.1661
# Epoch 13/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1480 - mae: 0.1480
# Epoch 14/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1428 - mae: 0.1428
# Epoch 15/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1371 - mae: 0.1371
# Epoch 16/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1291 - mae: 0.1291
# Epoch 17/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1192 - mae: 0.1192
# Epoch 18/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1168 - mae: 0.1168
# Epoch 19/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1122 - mae: 0.1122
# Epoch 20/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1112 - mae: 0.1112
# Epoch 21/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1069 - mae: 0.1069
# Epoch 22/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1031 - mae: 0.1031
# Epoch 23/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0962 - mae: 0.0962
# Epoch 24/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0966 - mae: 0.0966
# Epoch 25/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0911 - mae: 0.0911
# Epoch 26/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0900 - mae: 0.0900
# Epoch 27/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0874 - mae: 0.0874
# Epoch 28/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0862 - mae: 0.0862
# Epoch 29/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0847 - mae: 0.0847
# Epoch 30/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0875 - mae: 0.0875
# Epoch 31/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0854 - mae: 0.0854
# Epoch 32/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0825 - mae: 0.0825
# Epoch 33/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0868 - mae: 0.0868
# Epoch 34/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0835 - mae: 0.0835
# Epoch 35/60
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0848 - mae: 0.0848
# Epoch 36/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0842 - mae: 0.0842
# Epoch 37/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0826 - mae: 0.0826
# Epoch 38/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0858 - mae: 0.0858
# Epoch 39/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0849 - mae: 0.0849
# Epoch 40/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0822 - mae: 0.0822
# Epoch 41/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0854 - mae: 0.0854
# Epoch 42/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0821 - mae: 0.0821
# Epoch 43/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0826 - mae: 0.0826
# Epoch 44/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0802 - mae: 0.0802
# Epoch 45/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0848 - mae: 0.0848
# Epoch 46/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0816 - mae: 0.0816
# Epoch 47/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0830 - mae: 0.0830
# Epoch 48/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0809 - mae: 0.0809
# Epoch 49/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0808 - mae: 0.0808
# Epoch 50/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0786 - mae: 0.0786
# Epoch 51/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0801 - mae: 0.0801
# Epoch 52/60
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0782 - mae: 0.0782
# Epoch 53/60
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0802 - mae: 0.0802
# Epoch 54/60
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0822 - mae: 0.0822
# Epoch 55/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0814 - mae: 0.0814
# Epoch 56/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0787 - mae: 0.0787
# Epoch 57/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0806 - mae: 0.0806
# Epoch 58/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0769 - mae: 0.0769
# Epoch 59/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0798 - mae: 0.0798
# Epoch 60/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0775 - mae: 0.0775
# mae_week1 for municipality = 2 is 55.00
# mae_week2 for municipality = 2 is 56.49
# Epoch 1/60
# 2/2 [==============================] - 3s 13ms/step - loss: 0.5674 - mae: 0.5674
# Epoch 2/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3910 - mae: 0.3910
# Epoch 3/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2739 - mae: 0.2739
# Epoch 4/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2507 - mae: 0.2507
# Epoch 5/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2209 - mae: 0.2209
# Epoch 6/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2274 - mae: 0.2274
# Epoch 7/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2065 - mae: 0.2065
# Epoch 8/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1997 - mae: 0.1997
# Epoch 9/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1863 - mae: 0.1863
# Epoch 10/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1751 - mae: 0.1751
# Epoch 11/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1710 - mae: 0.1710
# Epoch 12/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1580 - mae: 0.1580
# Epoch 13/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1543 - mae: 0.1543
# Epoch 14/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1452 - mae: 0.1452
# Epoch 15/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1426 - mae: 0.1426
# Epoch 16/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1355 - mae: 0.1355
# Epoch 17/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1299 - mae: 0.1299
# Epoch 18/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1254 - mae: 0.1254
# Epoch 19/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1202 - mae: 0.1202
# Epoch 20/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1145 - mae: 0.1145
# Epoch 21/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1104 - mae: 0.1104
# Epoch 22/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1056 - mae: 0.1056
# Epoch 23/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1012 - mae: 0.1012
# Epoch 24/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0981 - mae: 0.0981
# Epoch 25/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0935 - mae: 0.0935
# Epoch 26/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0968 - mae: 0.0968
# Epoch 27/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0963 - mae: 0.0963
# Epoch 28/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0975 - mae: 0.0975
# Epoch 29/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0951 - mae: 0.0951
# Epoch 30/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0940 - mae: 0.0940
# Epoch 31/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0938 - mae: 0.0938
# Epoch 32/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0922 - mae: 0.0922
# Epoch 33/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0926 - mae: 0.0926
# Epoch 34/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0908 - mae: 0.0908
# Epoch 35/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0924 - mae: 0.0924
# Epoch 36/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0906 - mae: 0.0906
# Epoch 37/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0928 - mae: 0.0928
# Epoch 38/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0903 - mae: 0.0903
# Epoch 39/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0880 - mae: 0.0880
# Epoch 40/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0885 - mae: 0.0885
# Epoch 41/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0884 - mae: 0.0884
# Epoch 42/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0869 - mae: 0.0869
# Epoch 43/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0872 - mae: 0.0872
# Epoch 44/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0865 - mae: 0.0865
# Epoch 45/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0895 - mae: 0.0895
# Epoch 46/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0866 - mae: 0.0866
# Epoch 47/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0858 - mae: 0.0858
# Epoch 48/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0873 - mae: 0.0873
# Epoch 49/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0865 - mae: 0.0865
# Epoch 50/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0827 - mae: 0.0827
# Epoch 51/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0875 - mae: 0.0875
# Epoch 52/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0835 - mae: 0.0835
# Epoch 53/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0844 - mae: 0.0844
# Epoch 54/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0882 - mae: 0.0882
# Epoch 55/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0846 - mae: 0.0846
# Epoch 56/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0848 - mae: 0.0848
# Epoch 57/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0898 - mae: 0.0898
# Epoch 58/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0813 - mae: 0.0813
# Epoch 59/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0867 - mae: 0.0867
# Epoch 60/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0861 - mae: 0.0861
# mae_week1 for municipality = 3 is 166.06
# mae_week2 for municipality = 3 is 154.72
# Epoch 1/60
# 2/2 [==============================] - 3s 12ms/step - loss: 0.5487 - mae: 0.5487
# Epoch 2/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.3597 - mae: 0.3597
# Epoch 3/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3173 - mae: 0.3173
# Epoch 4/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2608 - mae: 0.2608
# Epoch 5/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2654 - mae: 0.2654
# Epoch 6/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2578 - mae: 0.2578
# Epoch 7/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2283 - mae: 0.2283
# Epoch 8/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2142 - mae: 0.2142
# Epoch 9/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2104 - mae: 0.2104
# Epoch 10/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2066 - mae: 0.2066
# Epoch 11/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1975 - mae: 0.1975
# Epoch 12/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1836 - mae: 0.1836
# Epoch 13/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1752 - mae: 0.1752
# Epoch 14/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1699 - mae: 0.1699
# Epoch 15/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1652 - mae: 0.1652
# Epoch 16/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1575 - mae: 0.1575
# Epoch 17/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1501 - mae: 0.1501
# Epoch 18/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1462 - mae: 0.1462
# Epoch 19/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1381 - mae: 0.1381
# Epoch 20/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1325 - mae: 0.1325
# Epoch 21/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1263 - mae: 0.1263
# Epoch 22/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1227 - mae: 0.1227
# Epoch 23/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1219 - mae: 0.1219
# Epoch 24/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1212 - mae: 0.1212
# Epoch 25/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1213 - mae: 0.1213
# Epoch 26/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1218 - mae: 0.1218
# Epoch 27/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1237 - mae: 0.1237
# Epoch 28/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1227 - mae: 0.1227
# Epoch 29/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1178 - mae: 0.1178
# Epoch 30/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1170 - mae: 0.1170
# Epoch 31/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1225 - mae: 0.1225
# Epoch 32/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1180 - mae: 0.1180
# Epoch 33/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1180 - mae: 0.1180
# Epoch 34/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1151 - mae: 0.1151
# Epoch 35/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1162 - mae: 0.1162
# Epoch 36/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1135 - mae: 0.1135
# Epoch 37/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1106 - mae: 0.1106
# Epoch 38/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1103 - mae: 0.1103
# Epoch 39/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1107 - mae: 0.1107
# Epoch 40/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1072 - mae: 0.1072
# Epoch 41/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1069 - mae: 0.1069
# Epoch 42/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1063 - mae: 0.1063
# Epoch 43/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1039 - mae: 0.1039
# Epoch 44/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1043 - mae: 0.1043
# Epoch 45/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1040 - mae: 0.1040
# Epoch 46/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1023 - mae: 0.1023
# Epoch 47/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1024 - mae: 0.1024
# Epoch 48/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1016 - mae: 0.1016
# Epoch 49/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0992 - mae: 0.0992
# Epoch 50/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1036 - mae: 0.1036
# Epoch 51/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0989 - mae: 0.0989
# Epoch 52/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0943 - mae: 0.0943
# Epoch 53/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0972 - mae: 0.0972
# Epoch 54/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0933 - mae: 0.0933
# Epoch 55/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0947 - mae: 0.0947
# Epoch 56/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0945 - mae: 0.0945
# Epoch 57/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0923 - mae: 0.0923
# Epoch 58/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0919 - mae: 0.0919
# Epoch 59/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0954 - mae: 0.0954
# Epoch 60/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0900 - mae: 0.0900
# mae_week1 for municipality = 4 is 402.51
# mae_week2 for municipality = 4 is 408.12
# Epoch 1/60
# 2/2 [==============================] - 2s 12ms/step - loss: 0.2870 - mae: 0.2870
# Epoch 2/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1967 - mae: 0.1967
# Epoch 3/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1345 - mae: 0.1345
# Epoch 4/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1314 - mae: 0.1314
# Epoch 5/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1249 - mae: 0.1249
# Epoch 6/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1121 - mae: 0.1121
# Epoch 7/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0996 - mae: 0.0996
# Epoch 8/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0982 - mae: 0.0982
# Epoch 9/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0956 - mae: 0.0956
# Epoch 10/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0914 - mae: 0.0914
# Epoch 11/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0864 - mae: 0.0864
# Epoch 12/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0830 - mae: 0.0830
# Epoch 13/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0822 - mae: 0.0822
# Epoch 14/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0807 - mae: 0.0807
# Epoch 15/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0799 - mae: 0.0799
# Epoch 16/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0785 - mae: 0.0785
# Epoch 17/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0770 - mae: 0.0770
# Epoch 18/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0774 - mae: 0.0774
# Epoch 19/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0783 - mae: 0.0783
# Epoch 20/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0767 - mae: 0.0767
# Epoch 21/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0768 - mae: 0.0768
# Epoch 22/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0763 - mae: 0.0763
# Epoch 23/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0756 - mae: 0.0756
# Epoch 24/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0754 - mae: 0.0754
# Epoch 25/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0749 - mae: 0.0749
# Epoch 26/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0754 - mae: 0.0754
# Epoch 27/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0745 - mae: 0.0745
# Epoch 28/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0753 - mae: 0.0753
# Epoch 29/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0760 - mae: 0.0760
# Epoch 30/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0742 - mae: 0.0742
# Epoch 31/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0744 - mae: 0.0744
# Epoch 32/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0746 - mae: 0.0746
# Epoch 33/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0740 - mae: 0.0740
# Epoch 34/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0759 - mae: 0.0759
# Epoch 35/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0734 - mae: 0.0734
# Epoch 36/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0742 - mae: 0.0742
# Epoch 37/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0727 - mae: 0.0727
# Epoch 38/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0731 - mae: 0.0731
# Epoch 39/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0729 - mae: 0.0729
# Epoch 40/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0726 - mae: 0.0726
# Epoch 41/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0727 - mae: 0.0727
# Epoch 42/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0743 - mae: 0.0743
# Epoch 43/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0721 - mae: 0.0721
# Epoch 44/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0732 - mae: 0.0732
# Epoch 45/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0730 - mae: 0.0730
# Epoch 46/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0713 - mae: 0.0713
# Epoch 47/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0742 - mae: 0.0742
# Epoch 48/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0720 - mae: 0.0720
# Epoch 49/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0728 - mae: 0.0728
# Epoch 50/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0720 - mae: 0.0720
# Epoch 51/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0720 - mae: 0.0720
# Epoch 52/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0726 - mae: 0.0726
# Epoch 53/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0714 - mae: 0.0714
# Epoch 54/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0706 - mae: 0.0706
# Epoch 55/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0711 - mae: 0.0711
# Epoch 56/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0704 - mae: 0.0704
# Epoch 57/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0708 - mae: 0.0708
# Epoch 58/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0708 - mae: 0.0708
# Epoch 59/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0704 - mae: 0.0704
# Epoch 60/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0704 - mae: 0.0704
# mae_week1 for municipality = 5 is 46.73
# mae_week2 for municipality = 5 is 46.39
# Epoch 1/60
# 2/2 [==============================] - 2s 14ms/step - loss: 0.3258 - mae: 0.3258
# Epoch 2/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2245 - mae: 0.2245
# Epoch 3/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1581 - mae: 0.1581
# Epoch 4/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1337 - mae: 0.1337
# Epoch 5/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1158 - mae: 0.1158
# Epoch 6/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1181 - mae: 0.1181
# Epoch 7/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1043 - mae: 0.1043
# Epoch 8/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0960 - mae: 0.0960
# Epoch 9/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0927 - mae: 0.0927
# Epoch 10/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0834 - mae: 0.0834
# Epoch 11/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0798 - mae: 0.0798
# Epoch 12/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0747 - mae: 0.0747
# Epoch 13/60
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0746 - mae: 0.0746
# Epoch 14/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0694 - mae: 0.0694
# Epoch 15/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0654 - mae: 0.0654
# Epoch 16/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0631 - mae: 0.0631
# Epoch 17/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0612 - mae: 0.0612
# Epoch 18/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0610 - mae: 0.0610
# Epoch 19/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0596 - mae: 0.0596
# Epoch 20/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0572 - mae: 0.0572
# Epoch 21/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0580 - mae: 0.0580
# Epoch 22/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0559 - mae: 0.0559
# Epoch 23/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0540 - mae: 0.0540
# Epoch 24/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0526 - mae: 0.0526
# Epoch 25/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0516 - mae: 0.0516
# Epoch 26/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0510 - mae: 0.0510
# Epoch 27/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0495 - mae: 0.0495
# Epoch 28/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0493 - mae: 0.0493
# Epoch 29/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0478 - mae: 0.0478
# Epoch 30/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0486 - mae: 0.0486
# Epoch 31/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0483 - mae: 0.0483
# Epoch 32/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0488 - mae: 0.0488
# Epoch 33/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0476 - mae: 0.0476
# Epoch 34/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0462 - mae: 0.0462
# Epoch 35/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0459 - mae: 0.0459
# Epoch 36/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0459 - mae: 0.0459
# Epoch 37/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0451 - mae: 0.0451
# Epoch 38/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0452 - mae: 0.0452
# Epoch 39/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0452 - mae: 0.0452
# Epoch 40/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0450 - mae: 0.0450
# Epoch 41/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0452 - mae: 0.0452
# Epoch 42/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0447 - mae: 0.0447
# Epoch 43/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0456 - mae: 0.0456
# Epoch 44/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0458 - mae: 0.0458
# Epoch 45/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0441 - mae: 0.0441
# Epoch 46/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0454 - mae: 0.0454
# Epoch 47/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0453 - mae: 0.0453
# Epoch 48/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0458 - mae: 0.0458
# Epoch 49/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0442 - mae: 0.0442
# Epoch 50/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0457 - mae: 0.0457
# Epoch 51/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0459 - mae: 0.0459
# Epoch 52/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0446 - mae: 0.0446
# Epoch 53/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0451 - mae: 0.0451
# Epoch 54/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0463 - mae: 0.0463
# Epoch 55/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0476 - mae: 0.0476
# Epoch 56/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0443 - mae: 0.0443
# Epoch 57/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0450 - mae: 0.0450
# Epoch 58/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0424 - mae: 0.0424
# Epoch 59/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0447 - mae: 0.0447
# Epoch 60/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0437 - mae: 0.0437
# mae_week1 for municipality = 6 is 92.84
# mae_week2 for municipality = 6 is 290.63
# Epoch 1/60
# 2/2 [==============================] - 3s 12ms/step - loss: 0.5148 - mae: 0.5148
# Epoch 2/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3213 - mae: 0.3213
# Epoch 3/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2417 - mae: 0.2417
# Epoch 4/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2277 - mae: 0.2277
# Epoch 5/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1726 - mae: 0.1726
# Epoch 6/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1815 - mae: 0.1815
# Epoch 7/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1649 - mae: 0.1649
# Epoch 8/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1398 - mae: 0.1398
# Epoch 9/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1349 - mae: 0.1349
# Epoch 10/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.1268 - mae: 0.1268
# Epoch 11/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1117 - mae: 0.1117
# Epoch 12/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1052 - mae: 0.1052
# Epoch 13/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0960 - mae: 0.0960
# Epoch 14/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0841 - mae: 0.0841
# Epoch 15/60
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0810 - mae: 0.0810
# Epoch 16/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0797 - mae: 0.0797
# Epoch 17/60
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0735 - mae: 0.0735
# Epoch 18/60
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0740 - mae: 0.0740
# Epoch 19/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0691 - mae: 0.0691
# Epoch 20/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0664 - mae: 0.0664
# Epoch 21/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0625 - mae: 0.0625
# Epoch 22/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0611 - mae: 0.0611
# Epoch 23/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0598 - mae: 0.0598
# Epoch 24/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0563 - mae: 0.0563
# Epoch 25/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0546 - mae: 0.0546
# Epoch 26/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0537 - mae: 0.0537
# Epoch 27/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0515 - mae: 0.0515
# Epoch 28/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0529 - mae: 0.0529
# Epoch 29/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0516 - mae: 0.0516
# Epoch 30/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0521 - mae: 0.0521
# Epoch 31/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0514 - mae: 0.0514
# Epoch 32/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0522 - mae: 0.0522
# Epoch 33/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0523 - mae: 0.0523
# Epoch 34/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0536 - mae: 0.0536
# Epoch 35/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0510 - mae: 0.0510
# Epoch 36/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0526 - mae: 0.0526
# Epoch 37/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0541 - mae: 0.0541
# Epoch 38/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0535 - mae: 0.0535
# Epoch 39/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0504 - mae: 0.0504
# Epoch 40/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0546 - mae: 0.0546
# Epoch 41/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0531 - mae: 0.0531
# Epoch 42/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0505 - mae: 0.0505
# Epoch 43/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0541 - mae: 0.0541
# Epoch 44/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0507 - mae: 0.0507
# Epoch 45/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0522 - mae: 0.0522
# Epoch 46/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0508 - mae: 0.0508
# Epoch 47/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0485 - mae: 0.0485
# Epoch 48/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0500 - mae: 0.0500
# Epoch 49/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0481 - mae: 0.0481
# Epoch 50/60
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0489 - mae: 0.0489
# Epoch 51/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0485 - mae: 0.0485
# Epoch 52/60
# 2/2 [==============================] - ETA: 0s - loss: 0.0468 - mae: 0.046 - 0s 15ms/step - loss: 0.0483 - mae: 0.0483
# Epoch 53/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0478 - mae: 0.0478
# Epoch 54/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0480 - mae: 0.0480
# Epoch 55/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0480 - mae: 0.0480
# Epoch 56/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0488 - mae: 0.0488
# Epoch 57/60
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0506 - mae: 0.0506
# Epoch 58/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0530 - mae: 0.0530
# Epoch 59/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0507 - mae: 0.0507
# Epoch 60/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0489 - mae: 0.0489
# mae_week1 for municipality = 7 is 112.38
# mae_week2 for municipality = 7 is 95.74
# Epoch 1/60
# 2/2 [==============================] - 3s 11ms/step - loss: 0.3234 - mae: 0.3234
# Epoch 2/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1911 - mae: 0.1911
# Epoch 3/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1528 - mae: 0.1528
# Epoch 4/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1416 - mae: 0.1416
# Epoch 5/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1189 - mae: 0.1189
# Epoch 6/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1257 - mae: 0.1257
# Epoch 7/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1124 - mae: 0.1124
# Epoch 8/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1027 - mae: 0.1027
# Epoch 9/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1005 - mae: 0.1005
# Epoch 10/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0950 - mae: 0.0950
# Epoch 11/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0895 - mae: 0.0895
# Epoch 12/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0849 - mae: 0.0849
# Epoch 13/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0787 - mae: 0.0787
# Epoch 14/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0735 - mae: 0.0735
# Epoch 15/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0687 - mae: 0.0687
# Epoch 16/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0651 - mae: 0.0651
# Epoch 17/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0621 - mae: 0.0621
# Epoch 18/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0597 - mae: 0.0597
# Epoch 19/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0574 - mae: 0.0574
# Epoch 20/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0554 - mae: 0.0554
# Epoch 21/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0535 - mae: 0.0535
# Epoch 22/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0498 - mae: 0.0498
# Epoch 23/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0486 - mae: 0.0486
# Epoch 24/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0459 - mae: 0.0459
# Epoch 25/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0452 - mae: 0.0452
# Epoch 26/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0443 - mae: 0.0443
# Epoch 27/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0455 - mae: 0.0455
# Epoch 28/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0465 - mae: 0.0465
# Epoch 29/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0431 - mae: 0.0431
# Epoch 30/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0457 - mae: 0.0457
# Epoch 31/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0439 - mae: 0.0439
# Epoch 32/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0422 - mae: 0.0422
# Epoch 33/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0417 - mae: 0.0417
# Epoch 34/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0411 - mae: 0.0411
# Epoch 35/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0409 - mae: 0.0409
# Epoch 36/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0420 - mae: 0.0420
# Epoch 37/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0415 - mae: 0.0415
# Epoch 38/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0411 - mae: 0.0411
# Epoch 39/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0422 - mae: 0.0422
# Epoch 40/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0402 - mae: 0.0402
# Epoch 41/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0403 - mae: 0.0403
# Epoch 42/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0409 - mae: 0.0409
# Epoch 43/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0395 - mae: 0.0395
# Epoch 44/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0397 - mae: 0.0397
# Epoch 45/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0395 - mae: 0.0395
# Epoch 46/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0385 - mae: 0.0385
# Epoch 47/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0384 - mae: 0.0384
# Epoch 48/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0386 - mae: 0.0386
# Epoch 49/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0383 - mae: 0.0383
# Epoch 50/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0383 - mae: 0.0383
# Epoch 51/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0377 - mae: 0.0377
# Epoch 52/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0370 - mae: 0.0370
# Epoch 53/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0365 - mae: 0.0365
# Epoch 54/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0366 - mae: 0.0366
# Epoch 55/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0362 - mae: 0.0362
# Epoch 56/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0362 - mae: 0.0362
# Epoch 57/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0359 - mae: 0.0359
# Epoch 58/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0363 - mae: 0.0363
# Epoch 59/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0386 - mae: 0.0386
# Epoch 60/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0388 - mae: 0.0388
# mae_week1 for municipality = 8 is 119.03
# mae_week2 for municipality = 8 is 118.34
# Epoch 1/60
# 2/2 [==============================] - 3s 12ms/step - loss: 0.4657 - mae: 0.4657
# Epoch 2/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2793 - mae: 0.2793
# Epoch 3/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1967 - mae: 0.1967
# Epoch 4/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1844 - mae: 0.1844
# Epoch 5/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1619 - mae: 0.1619
# Epoch 6/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1549 - mae: 0.1549
# Epoch 7/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1218 - mae: 0.1218
# Epoch 8/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1311 - mae: 0.1311
# Epoch 9/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1225 - mae: 0.1225
# Epoch 10/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1042 - mae: 0.1042
# Epoch 11/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1024 - mae: 0.1024
# Epoch 12/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0905 - mae: 0.0905
# Epoch 13/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0853 - mae: 0.0853
# Epoch 14/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0763 - mae: 0.0763
# Epoch 15/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0684 - mae: 0.0684
# Epoch 16/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0674 - mae: 0.0674
# Epoch 17/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0681 - mae: 0.0681
# Epoch 18/60
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0659 - mae: 0.0659
# Epoch 19/60
# 2/2 [==============================] - 0s 18ms/step - loss: 0.0642 - mae: 0.0642
# Epoch 20/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0653 - mae: 0.0653
# Epoch 21/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0632 - mae: 0.0632
# Epoch 22/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0586 - mae: 0.0586
# Epoch 23/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0581 - mae: 0.0581
# Epoch 24/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0569 - mae: 0.0569
# Epoch 25/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0559 - mae: 0.0559
# Epoch 26/60
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0532 - mae: 0.0532
# Epoch 27/60
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0531 - mae: 0.0531
# Epoch 28/60
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0525 - mae: 0.0525
# Epoch 29/60
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0520 - mae: 0.0520
# Epoch 30/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0512 - mae: 0.0512
# Epoch 31/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0497 - mae: 0.0497
# Epoch 32/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0504 - mae: 0.0504
# Epoch 33/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0478 - mae: 0.0478
# Epoch 34/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0471 - mae: 0.0471
# Epoch 35/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0470 - mae: 0.0470
# Epoch 36/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0506 - mae: 0.0506
# Epoch 37/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0474 - mae: 0.0474
# Epoch 38/60
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0465 - mae: 0.0465
# Epoch 39/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0533 - mae: 0.0533
# Epoch 40/60
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0448 - mae: 0.0448
# Epoch 41/60
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0514 - mae: 0.0514
# Epoch 42/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0490 - mae: 0.0490
# Epoch 43/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0493 - mae: 0.0493
# Epoch 44/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0477 - mae: 0.0477
# Epoch 45/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0478 - mae: 0.0478
# Epoch 46/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0515 - mae: 0.0515
# Epoch 47/60
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0504 - mae: 0.0504
# Epoch 48/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0457 - mae: 0.0457
# Epoch 49/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0476 - mae: 0.0476
# Epoch 50/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0466 - mae: 0.0466
# Epoch 51/60
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0481 - mae: 0.0481
# Epoch 52/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0453 - mae: 0.0453
# Epoch 53/60
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0467 - mae: 0.0467
# Epoch 54/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0465 - mae: 0.0465
# Epoch 55/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0454 - mae: 0.0454
# Epoch 56/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0471 - mae: 0.0471
# Epoch 57/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0486 - mae: 0.0486
# Epoch 58/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0462 - mae: 0.0462
# Epoch 59/60
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0449 - mae: 0.0449
# Epoch 60/60
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0454 - mae: 0.0454
# mae_week1 for municipality = 9 is 85.29
# mae_week2 for municipality = 9 is 64.64
#
# Dictionary of each municipality MAE evaluation on TestWeek 1 and TestWeek 2
# ---------------------------------------------------------------------------
# OrderedDict([(0, [49.876474047464036, 324.47848825606087]), (1, [45.04710690937345, 22.622471158466645]), (2, [55.004298618861604, 56.485967726934526]), (3, [166.06172543480284, 154.72298225523934]), (4, [402.5083395337302, 408.1177484421503]), (5, [46.72962909274631, 46.38859588380844]), (6, [92.84421018570188, 290.6295446971106]), (7, [112.38292003813244, 95.73797510540675]), (8, [119.02932206411211, 118.34067063104538]), (9, [85.29186188228546, 64.63514249286955])])
#
# **************** RESULTS *********************
#
# mae_week1 for all municipalities is 118.03
# mae_week2 for all municipalities is 159.73
# mae_overall for all municipalities and both weeks combined is 138.88
